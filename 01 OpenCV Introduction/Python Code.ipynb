# %% [markdown]
# # **Setup**

# %%
# !python3 --version

from psutil import *
print('CPU Core: ',cpu_count())
print(f'System RAM: {virtual_memory()[0]/(1024**3)} GB')
# Out:
# Python 3.11.4
# CPU Core:  8
# System RAM: 8.0 GB

# %%
import cv2
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # **Basic Operations**

# %% [markdown]
# ## **Read Image File**

# %%
input = cv2.imread('Image01.jpg')
input.shape
# Out:
# (2193, 3899, 3)

# %% [markdown]
# ## **Show Image File**

# %%
plt.imshow(input)

# %%
cv2.imshow('Hello World',input)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## **Save Image Files**

# %%
cv2.imwrite('output.jpg',input)
# Out:
# True

# %% [markdown]
# ## **Connect Camera**

# %%
video_capture = cv2.VideoCapture(0)

# %% [markdown]
# # **Detect Face**

# %%
face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')

# %%
image = cv2.imread('image_examples/Modi.jpg')
plt.imshow(image,cmap='brg')

# %%
# image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
# plt.imshow(image_gray,'brg')

# %%
faces = face_classifier.detectMultiScale(image,1.3,5)

if faces == ():
    print('No Faces Found!')

for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)
    cv2.imshow('Detected Faces',image)
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# /var/folders/c0/06v83ym56nl05bjhdwr6hz9m0000gp/T/ipykernel_16715/3646530592.py:3: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():

# %% [markdown]
# # **Detect Face & Eyes**

# %%
eye_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_eye.xml')

# %%
image = cv2.imread('image_examples/Modi.jpg')
plt.imshow(image,cmap='brg')

# %%
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)

# %%
from matplotlib.pyplot import gray


faces = face_classifier.detectMultiScale(image,1.3,5)

if faces == ():
    print('No Faces Found!')

for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)
    cv2.imshow('Detected Faces',image)
    cv2.waitKey(0)

    ROI_Gray = image_gray[y:y+h,x:x+w]
    ROI_Color = image[y:y+h,x:x+w]
    
    eyes = eye_classifier.detectMultiScale(ROI_Gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(ROI_Color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
        cv2.imshow('Detected Eyes',image)
        cv2.waitKey(0)
        
cv2.destroyAllWindows()
# Out:
# /var/folders/c0/06v83ym56nl05bjhdwr6hz9m0000gp/T/ipykernel_16715/572819616.py:6: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
